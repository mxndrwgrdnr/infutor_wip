# %%
import pandas as pd
import dask.dataframe as dd
from dask.diagnostics import ProgressBar
from shapely.geometry import Point
import geopandas as gpd
import numpy as np

# %% [markdown]
# ### Load data

# %%
moves = dd.read_parquet('../data/moves_long.parquet', columns=['pid', 'from_addrid', 'from_effdate', 'to_addrid', 'to_effdate'])

# %%
moves.head()
# Out:
#                pid  from_addrid  from_effdate    to_addrid  to_effdate
# 0  Y39394398562992  202102955.0      201211.0   29500074.0    201406.0
# 0  Y39394652594475  119078295.0      197806.0   45967481.0    199304.0
# 0  Y39394886301278   32888015.0      199304.0    8971746.0    199406.0
# 0  Y39394652594475   45967481.0      199304.0  224561475.0    200002.0
# 0  Y39394445944928  187599562.0      200404.0    9920094.0    200912.0

# %%
properties = dd.read_csv(
    '/home/data/infutor/Property/bay_area_properties*',
    dtype={'PROP_CENSUSTRACT': str, 'PROP_FIPSCD': str},
    usecols=['ADDRID', 'ADDRID2', 'DPV', 'PROP_LATITUDE', 'PROP_LONGITUDE', 'PROP_FIPSCD',
             'PROP_CENSUSTRACT', 'PROP_MUNINAME', 'PROP_OWNEROCC', 'PROP_QLTY',
             'PROP_VALCALC', 'PROP_UNVBLDSQFT', 'PROP_BEDRMS']
)

# %%
properties.head()
# Out:
#    DPV PROP_FIPSCD PROP_CENSUSTRACT               PROP_MUNINAME  \
# 0  NaN       06041       1011001023  NOVATO UNIFIED SCHOOL AREA
# 1  NaN       06095       2501052020                     VALLEJO
# 2  NaN       06095       2524022097              UNINCORPORATED
# 3  NaN       06095       2522022025                   FAIRFIELD
# 4  NaN       06095       2523051142              UNINCORPORATED
#
#    PROP_LATITUDE  PROP_LONGITUDE PROP_OWNEROCC PROP_QLTY  PROP_VALCALC  \
# 0            NaN             NaN           NaN       NaN           NaN
# 1            NaN             NaN             A       NaN           NaN
# 2            NaN             NaN           NaN       NaN           NaN
# 3            NaN             NaN           NaN       NaN           NaN
# 4            NaN             NaN           NaN       NaN           NaN
#
#    PROP_UNVBLDSQFT  PROP_BEDRMS     ADDRID    ADDRID2
# 0              NaN          NaN  248051559  239867607
# 1              NaN          NaN  660643601  213239347
# 2              NaN          NaN  248051559  137069087
# 3              NaN          NaN  248051559   83681844
# 4              NaN          NaN  248051559  140602177

# %% [markdown]
# ### Filter data

# %%
prop_w_geog = properties[
    properties['PROP_LATITUDE'].notnull() & properties['PROP_LONGITUDE'].notnull() & 
    properties['DPV'].isin(['D', 'S', 'Y']) &
    properties['PROP_FIPSCD'].isin(['06001', '06013', '06041', '06055', '06075', '06081', '06085', '06095', '06097'])
]

# %% [markdown]
# ### Merge w/ properties

# %% [markdown]
# #### Merge on from ADDRID

# %%
moves = moves.set_index('from_addrid')

# %%
prop_w_geog = prop_w_geog.set_index('ADDRID')

# %%
prop_w_geog.head()
# Out:
#        DPV PROP_FIPSCD PROP_CENSUSTRACT PROP_MUNINAME  PROP_LATITUDE  \
# ADDRID
# 1838     Y       06081       6057002008           NaN      37.540800
# 1840     Y       06081       6009001019           NaN      37.704800
# 1843     Y       06075       0113002003           NaN      37.793109
# 1845     Y       06075       0131012005           NaN      37.791416
# 1846     Y       06075       0214002003           NaN      37.749214
#
#         PROP_LONGITUDE PROP_OWNEROCC PROP_QLTY  PROP_VALCALC  PROP_UNVBLDSQFT  \
# ADDRID
# 1838        -122.34700             O       NaN     3927917.0           5670.0
# 1840        -122.48000             A       NaN       93198.0           1330.0
# 1843        -122.40902             O       NaN     1159096.0           1225.0
# 1845        -122.42425             O       QEX      776701.0           1500.0
# 1846        -122.42833             O       NaN     3774000.0           1250.0
#
#         PROP_BEDRMS   ADDRID2
# ADDRID
# 1838            5.0      1838
# 1840            2.0  20814887
# 1843            2.0      1843
# 1845            2.0      1845
# 1846            NaN      1846

# %%
merged_1 = moves.merge(prop_w_geog, left_index=True, right_index=True)

# %%
with ProgressBar():
    merged_1 = merged_1.rename(columns={'PROP_LATITUDE': 'from_lat', 'PROP_LONGITUDE': 'from_lon'}).compute()
# Out:
# [########################################] | 100% Completed | 54.6s

# %%
moves_w_from_geog = merged_1.reset_index().rename(columns={'index': 'from_addrid'})

# %%
moves_w_from_geog.head()
# Out:
#    from_addrid              pid  from_effdate    to_addrid  to_effdate DPV  \
# 0       1838.0  Y39394800924986      200212.0  201439665.0    200509.0   Y
# 1       1840.0  Y39394431814516      198007.0   20814887.0    199912.0   Y
# 2       1840.0  Y39394830916146      199606.0   84669265.0    200002.0   Y
# 3       1843.0  Y39394615847176      199901.0   56523799.0    200004.0   Y
# 4       1845.0  Y39394668254684      198007.0   71161461.0    198503.0   Y
#
#   PROP_FIPSCD PROP_CENSUSTRACT PROP_MUNINAME   from_lat   from_lon  \
# 0       06081       6057002008           NaN  37.540800 -122.34700
# 1       06081       6009001019           NaN  37.704800 -122.48000
# 2       06081       6009001019           NaN  37.704800 -122.48000
# 3       06075       0113002003           NaN  37.793109 -122.40902
# 4       06075       0131012005           NaN  37.791416 -122.42425
#
#   PROP_OWNEROCC PROP_QLTY  PROP_VALCALC  PROP_UNVBLDSQFT  PROP_BEDRMS  \
# 0             O       NaN     3927917.0           5670.0          5.0
# 1             A       NaN       93198.0           1330.0          2.0
# 2             A       NaN       93198.0           1330.0          2.0
# 3             O       NaN     1159096.0           1225.0          2.0
# 4             O       QEX      776701.0           1500.0          2.0
#
#     ADDRID2
# 0      1838
# 1  20814887
# 2  20814887
# 3      1843
# 4      1845

# %%
len(moves_w_from_geog)
# Out:
# 5769536

# %% [markdown]
# #### Merge on to ADDRID

# %%
moves_w_from_geog = moves_w_from_geog.set_index('to_addrid')

# %%
merged_2 = prop_w_geog.merge(moves_w_from_geog, left_index=True, right_index=True, suffixes=('_to', '_from'))

# %%
with ProgressBar():
    merged_2 = merged_2.rename(columns={'PROP_LATITUDE': 'to_lat', 'PROP_LONGITUDE': 'to_lon'}).compute()
# Out:
# [########################################] | 100% Completed |  1min 21.4s

# %%
moves_w_geog = merged_2.reset_index().rename(columns={'index': 'to_addrid'})

# %%
moves_w_geog.head()
# Out:
#    to_addrid DPV_to PROP_FIPSCD_to PROP_CENSUSTRACT_to PROP_MUNINAME_to  \
# 0       1838      Y          06081          6057002008              NaN
# 1       1838      Y          06081          6057002008              NaN
# 2       1840      Y          06081          6009001019              NaN
# 3       1851      Y          06075          0216001001              NaN
# 4       1852      Y          06075          0307002001              NaN
#
#       to_lat     to_lon PROP_OWNEROCC_to PROP_QLTY_to  PROP_VALCALC_to  ...  \
# 0  37.540800 -122.34700                O          NaN        3927917.0  ...
# 1  37.540800 -122.34700                O          NaN        3927917.0  ...
# 2  37.704800 -122.48000                A          NaN          93198.0  ...
# 3  37.747154 -122.43502                A          QAV         407914.0  ...
# 4  37.735242 -122.44147                O          NaN         699320.0  ...
#
#    PROP_CENSUSTRACT_from  PROP_MUNINAME_from   from_lat   from_lon  \
# 0             6057004012                 NaN  37.556300 -122.35300
# 1             6028003002                 NaN  37.655700 -122.48500
# 2             5113021024      PALO ALTO CITY  37.445200 -122.16500
# 3             4046002008      OAKLAND INCORP  37.827700 -122.18700
# 4             1522023002                 NaN  38.464289 -122.67699
#
#   PROP_OWNEROCC_from  PROP_QLTY_from  PROP_VALCALC_from PROP_UNVBLDSQFT_from  \
# 0                  O             NaN          4767552.0               5290.0
# 1                  O             NaN           439898.0               2790.0
# 2                  A             QAV           409681.0               1307.0
# 3                  O             QAV           630299.0               3047.0
# 4                  O             QGO           361090.0               2136.0
#
#   PROP_BEDRMS_from ADDRID2_from
# 0              4.0     70211557
# 1              3.0    201439665
# 2              4.0    138608104
# 3              4.0    222110933
# 4              4.0    145806123
#
# [5 rows x 29 columns]

# %% [markdown]
# #### Drop duplicates

# %%
uniq_moves_w_geog = moves_w_geog.drop_duplicates(['pid', 'from_addrid', 'to_addrid'])

# %%
num_total_moves = len(moves)
num_matched_moves = len(uniq_moves_w_geog)
print(
    'Matched both properties to property records with geographies '
    'for {0} of {1} ({2}%) of relocation records.'.format(
        str(num_matched_moves), str(num_total_moves), str(round(100 * num_matched_moves / num_total_moves, 1))))
# Out:
# Matched both properties to property records with geographies for 3641224 of 11221531 (32.4%) of relocation records.

# %% [markdown]
# #### Compute move distances

# %%
uniq_moves_w_geog2 = uniq_moves_w_geog[[
    'pid', 'from_addrid', 'from_lat', 'from_lon', 'PROP_FIPSCD_from', 'PROP_CENSUSTRACT_from', 'PROP_MUNINAME_from',
    'PROP_OWNEROCC_from', 'PROP_QLTY_from', 'PROP_VALCALC_from', 'PROP_UNVBLDSQFT_from', 'PROP_BEDRMS_from', 'from_effdate',
    'to_addrid', 'to_lat', 'to_lon', 'PROP_FIPSCD_to', 'PROP_CENSUSTRACT_to', 'PROP_MUNINAME_to', 'PROP_OWNEROCC_to',
    'PROP_QLTY_to', 'PROP_VALCALC_to', 'PROP_UNVBLDSQFT_to', 'PROP_BEDRMS_to', 'to_effdate'
]]

# %%
def get_dist(df):
    
    moves_w_geog = df.copy()
    moves_w_geog['from_coords'] = list(zip(moves_w_geog.from_lon, moves_w_geog.from_lat))
    moves_w_geog['to_coords'] = list(zip(moves_w_geog.to_lon, moves_w_geog.to_lat))
    moves_w_geog['from_coords'] = moves_w_geog['from_coords'].apply(Point)
    moves_w_geog['to_coords'] = moves_w_geog['to_coords'].apply(Point)
    from_gs = gpd.GeoSeries(moves_w_geog['from_coords'], crs={'init' :'epsg:4326'}).to_crs(epsg='2768')
    to_gs = gpd.GeoSeries(moves_w_geog['to_coords'], crs={'init' :'epsg:4326'}).to_crs(epsg='2768')
    dists = from_gs.distance(to_gs)
    moves_w_geog['distance'] = dists

    return moves_w_geog[np.append(df.columns, 'distance')]

# %%
# %%time
ddf = dd.from_pandas(
    uniq_moves_w_geog2,
    npartitions=10000)
# Out:
# CPU times: user 14.7 s, sys: 966 ms, total: 15.6 s
# Wall time: 15.4 s

# %%
ddf.head()
# Out:
#                pid  from_addrid   from_lat   from_lon PROP_FIPSCD_from  \
# 0  Y39394867335546   70211557.0  37.556300 -122.35300            06081
# 1  Y39394800924986  201439665.0  37.655700 -122.48500            06081
# 2  Y39394610202108  145654720.0  37.445200 -122.16500            06085
# 3  Y39394843362955  222110933.0  37.827700 -122.18700            06001
# 4  Y39394415231837  145806123.0  38.464289 -122.67699            06097
#
#   PROP_CENSUSTRACT_from PROP_MUNINAME_from PROP_OWNEROCC_from PROP_QLTY_from  \
# 0            6057004012                NaN                  O            NaN
# 1            6028003002                NaN                  O            NaN
# 2            5113021024     PALO ALTO CITY                  A            QAV
# 3            4046002008     OAKLAND INCORP                  O            QAV
# 4            1522023002                NaN                  O            QGO
#
#    PROP_VALCALC_from  ...     to_lon  PROP_FIPSCD_to  PROP_CENSUSTRACT_to  \
# 0          4767552.0  ... -122.34700           06081           6057002008
# 1           439898.0  ... -122.34700           06081           6057002008
# 2           409681.0  ... -122.48000           06081           6009001019
# 3           630299.0  ... -122.43502           06075           0216001001
# 4           361090.0  ... -122.44147           06075           0307002001
#
#    PROP_MUNINAME_to  PROP_OWNEROCC_to  PROP_QLTY_to PROP_VALCALC_to  \
# 0               NaN                 O           NaN       3927917.0
# 1               NaN                 O           NaN       3927917.0
# 2               NaN                 A           NaN         93198.0
# 3               NaN                 A           QAV        407914.0
# 4               NaN                 O           NaN        699320.0
#
#   PROP_UNVBLDSQFT_to PROP_BEDRMS_to to_effdate
# 0             5670.0            5.0   200002.0
# 1             5670.0            5.0   201003.0
# 2             1330.0            2.0   201003.0
# 3             1145.0            2.0   200204.0
# 4             2642.0            3.0   199207.0
#
# [5 rows x 25 columns]

# %%
dtypes = uniq_moves_w_geog2.dtypes.apply(lambda x: x.name).to_dict()
dtypes.update({'distance': 'float'})

# %%
ddf = ddf.map_partitions(get_dist, meta=dtypes)

# %%
with ProgressBar():
    moves_w_dists = ddf.compute()
# Out:
# [########################################] | 100% Completed | 50min 40.9s

# %%
moves_w_dists.head()
# Out:
#                pid  from_addrid   from_lat   from_lon PROP_FIPSCD_from  \
# 0  Y39394867335546   70211557.0  37.556300 -122.35300            06081
# 1  Y39394800924986  201439665.0  37.655700 -122.48500            06081
# 2  Y39394610202108  145654720.0  37.445200 -122.16500            06085
# 3  Y39394843362955  222110933.0  37.827700 -122.18700            06001
# 4  Y39394415231837  145806123.0  38.464289 -122.67699            06097
#
#   PROP_CENSUSTRACT_from PROP_MUNINAME_from PROP_OWNEROCC_from PROP_QLTY_from  \
# 0            6057004012                NaN                  O            NaN
# 1            6028003002                NaN                  O            NaN
# 2            5113021024     PALO ALTO CITY                  A            QAV
# 3            4046002008     OAKLAND INCORP                  O            QAV
# 4            1522023002                NaN                  O            QGO
#
#    PROP_VALCALC_from  ...  PROP_FIPSCD_to  PROP_CENSUSTRACT_to  \
# 0          4767552.0  ...           06081           6057002008
# 1           439898.0  ...           06081           6057002008
# 2           409681.0  ...           06081           6009001019
# 3           630299.0  ...           06075           0216001001
# 4           361090.0  ...           06075           0307002001
#
#    PROP_MUNINAME_to  PROP_OWNEROCC_to  PROP_QLTY_to  PROP_VALCALC_to  \
# 0               NaN                 O           NaN        3927917.0
# 1               NaN                 O           NaN        3927917.0
# 2               NaN                 A           NaN          93198.0
# 3               NaN                 A           QAV         407914.0
# 4               NaN                 O           NaN         699320.0
#
#   PROP_UNVBLDSQFT_to PROP_BEDRMS_to to_effdate      distance
# 0             5670.0            5.0   200002.0   1800.050142
# 1             5670.0            5.0   201003.0  17638.119062
# 2             1330.0            2.0   201003.0  40053.036820
# 3             1145.0            2.0   200204.0  23603.668469
# 4             2642.0            3.0   199207.0  83514.351216
#
# [5 rows x 26 columns]

# %%
moves_w_dists.shape
# Out:
# (3641224, 26)

# %% [markdown]
# ### Merge demographics

# %%
# %%time
ddf = dd.from_pandas(
    moves_w_dists,
    npartitions=38).set_index('pid')
# Out:
# CPU times: user 26.2 s, sys: 0 ns, total: 26.2 s
# Wall time: 26 s

# %%
ddf.head()
# Out:
#                  from_addrid   from_lat   from_lon PROP_FIPSCD_from  \
# pid
# Y39394000021058  213725788.0  37.897100 -122.53400            06041
# Y39394000021058   65593649.0  37.888200 -122.54500            06041
# Y39394000054683  117484545.0  37.900100 -122.27400            06001
# Y39394000108630   65353580.0  37.775108 -122.48973            06075
# Y39394000314991  186863857.0  37.774000 -122.26000            06001
#
#                 PROP_CENSUSTRACT_from             PROP_MUNINAME_from  \
# pid
# Y39394000021058            1261002011                    MILL VALLEY
# Y39394000021058            1282002004  MILL VALLEY SCHOOL AREA TAMAL
# Y39394000054683            4212004007                BERKELEY INCORP
# Y39394000108630            0478013005                            NaN
# Y39394000314991            4279004000                 ALAMEDA INCORP
#
#                 PROP_OWNEROCC_from PROP_QLTY_from  PROP_VALCALC_from  \
# pid
# Y39394000021058                  O            QGO           784444.0
# Y39394000021058                  A            QGO           612199.0
# Y39394000054683                  A            QAV            85981.0
# Y39394000108630                NaN            NaN           130942.0
# Y39394000314991                  A            QAV           309321.0
#
#                  PROP_UNVBLDSQFT_from  ...  PROP_FIPSCD_to  \
# pid                                    ...
# Y39394000021058                1300.0  ...           06041
# Y39394000021058                2297.0  ...           06041
# Y39394000054683                1466.0  ...           06001
# Y39394000108630                3400.0  ...           06001
# Y39394000314991                1621.0  ...           06001
#
#                  PROP_CENSUSTRACT_to              PROP_MUNINAME_to  \
# pid
# Y39394000021058           1241001017  MILL VALLEY SCHOOL AREA ALTO
# Y39394000021058           1261002011                   MILL VALLEY
# Y39394000054683           4212001004               BERKELEY INCORP
# Y39394000108630           4014002010                OAKLAND INCORP
# Y39394000314991           4276002010                ALAMEDA INCORP
#
#                  PROP_OWNEROCC_to  PROP_QLTY_to PROP_VALCALC_to  \
# pid
# Y39394000021058               NaN           QGO        592507.0
# Y39394000021058                 O           QGO        784444.0
# Y39394000054683                 O           QAV        811687.0
# Y39394000108630                 A           QAV        326197.0
# Y39394000314991                 O           QAV        205785.0
#
#                 PROP_UNVBLDSQFT_to PROP_BEDRMS_to to_effdate      distance
# pid
# Y39394000021058             2890.0            5.0   201602.0   2039.664580
# Y39394000021058             1300.0            2.0   201303.0   1382.667421
# Y39394000054683             1078.0            2.0   201304.0    441.693361
# Y39394000108630             1269.0            2.0   201808.0  19625.242557
# Y39394000314991             1128.0            2.0   201706.0   1601.150776
#
# [5 rows x 25 columns]

# %%
demog_cols = ['PID', 'AGE', 'LOR', 'HOMEOWNERCD', 'EHI', 'PCTB', 'PCTW', 'PCTA', 'PCTH']

demog_dtypes = {col: float if col in ['AGE', 'LOR'] else str for col in demog_cols}

demog = dd.read_csv(
    '/home/data/infutor/NARC3/bay_area_mover*.csv',
    usecols=demog_cols,
    assume_missing=True,
    dtype=demog_dtypes).set_index('PID')

# %%
moves_w_demog = ddf.merge(demog, left_index=True, right_index=True)

# %%
with ProgressBar():
    moves_w_demog = moves_w_demog.compute()
# Out:
# [########################################] | 100% Completed |  1min 54.3s

# %%
num_total_moves = len(moves_w_dists)
num_moves_w_demog = len(moves_w_demog)

# %%
print('Matched movers to demographic profiles '
      'for {0} of {1} ({2}%) of relocation records.'.format(
        str(num_moves_w_demog), str(num_total_moves), str(round(100 * num_moves_w_demog / num_total_moves, 1))))
# Out:
# Matched movers to demographic profiles for 2212813 of 3641224 (60.8%) of relocation records.

# %% [markdown]
# ### Save outputs

# %%
moves_w_demog.index.name = 'pid'
moves_w_demog.reset_index(inplace=True)

# %%
moves_w_demog.to_csv('../data/moves_w_dists.csv', index=False)
