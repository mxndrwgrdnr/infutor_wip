# %%
import pandas as pd
import dask.dataframe as dd
from dask.diagnostics import ProgressBar
from shapely.geometry import Point
import geopandas as gpd
import numpy as np

# %% [markdown]
# ### Load data

# %%
moves = dd.read_csv(
    '../data/moves_w_dists.csv',
    dtype={'PROP_CENSUSTRACT_from': str, 'PROP_FIPSCD_from': str, 'PROP_CENSUSTRACT_to': str, 'PROP_FIPSCD_to': str},
    blocksize=25e6).set_index('pid')

# %%
moves.head()
# Out:
#                  from_addrid   from_lat   from_lon PROP_FIPSCD_from  \
# pid
# Y39394000021058   65593649.0  37.888200 -122.54500            06041
# Y39394000021058  213725788.0  37.897100 -122.53400            06041
# Y39394000054683  117484545.0  37.900100 -122.27400            06001
# Y39394000108630   65353580.0  37.775108 -122.48973            06075
# Y39394000231102  124297011.0  37.982800 -121.83700            06013
#
#                 PROP_CENSUSTRACT_from             PROP_MUNINAME_from  \
# pid
# Y39394000021058            1282002004  MILL VALLEY SCHOOL AREA TAMAL
# Y39394000021058            1261002011                    MILL VALLEY
# Y39394000054683            4212004007                BERKELEY INCORP
# Y39394000108630            0478013005                            NaN
# Y39394000231102            3551072003                            NaN
#
#                 PROP_OWNEROCC_from PROP_QLTY_from  PROP_VALCALC_from  \
# pid
# Y39394000021058                  A            QGO           612199.0
# Y39394000021058                  O            QGO           784444.0
# Y39394000054683                  A            QAV            85981.0
# Y39394000108630                NaN            NaN           130942.0
# Y39394000231102                  O            QGO           316975.0
#
#                  PROP_UNVBLDSQFT_from  ...  PROP_FIPSCD_to  \
# pid                                    ...
# Y39394000021058                2297.0  ...           06041
# Y39394000021058                1300.0  ...           06041
# Y39394000054683                1466.0  ...           06001
# Y39394000108630                3400.0  ...           06001
# Y39394000231102                2522.0  ...           06013
#
#                  PROP_CENSUSTRACT_to              PROP_MUNINAME_to  \
# pid
# Y39394000021058           1261002011                   MILL VALLEY
# Y39394000021058           1241001017  MILL VALLEY SCHOOL AREA ALTO
# Y39394000054683           4212001004               BERKELEY INCORP
# Y39394000108630           4014002010                OAKLAND INCORP
# Y39394000231102           3040052164                           NaN
#
#                  PROP_OWNEROCC_to PROP_QLTY_to PROP_VALCALC_to  \
# pid
# Y39394000021058                 O          QGO        784444.0
# Y39394000021058               NaN          QGO        592507.0
# Y39394000054683                 O          QAV        811687.0
# Y39394000108630                 A          QAV        326197.0
# Y39394000231102                 O          NaN        271688.0
#
#                 PROP_UNVBLDSQFT_to PROP_BEDRMS_to to_effdate      distance
# pid
# Y39394000021058             1300.0            2.0   201303.0   1382.667421
# Y39394000021058             2890.0            5.0   201602.0   2039.664580
# Y39394000054683             1078.0            2.0   201304.0    441.693361
# Y39394000108630             1269.0            2.0   201808.0  19625.242557
# Y39394000231102             2723.0            3.0   201007.0  20241.509295
#
# [5 rows x 24 columns]

# %%
moves.npartitions
# Out:
# 38

# %%
demog_cols = ['PID', 'AGE', 'LOR', 'HOMEOWNERCD', 'EHI', 'PCTB', 'PCTW', 'PCTA', 'PCTH']

# %%
demog_dtypes = {col: float if col in ['AGE', 'LOR'] else str for col in demog_cols}

# %%
demog = dd.read_csv(
    '/home/data/infutor/NARC3/bay_area_mover*.csv',
    usecols=demog_cols,
    assume_missing=True,
    dtype=demog_dtypes).set_index('PID')

# %%
demog.head()
# Out:
#                   AGE   LOR HOMEOWNERCD EHI PCTB PCTW PCTH PCTA
# PID
# Y39394000101840   NaN   9.0           H   D    S    I    O    R
# Y39394000112368  78.0  13.0           H   D    T    C    R    T
# Y39394000159895   NaN   1.0         NaN   H    T    E    S    S
# Y39394000190759  52.0   8.0           H   H    T    I    Q    O
# Y39394000215765  73.0  15.0           R   E    S    M    P    N

# %% [markdown]
# ### Merge data

# %%
moves_w_demog = moves.merge(demog, left_index=True, right_index=True)

# %%
with ProgressBar():
    moves_w_demog = moves_w_demog.compute()
# Out:
# [########################################] | 100% Completed |  2min 22.0s

# %%
moves_w_demog.head()
# Out:
#                  from_addrid   from_lat   from_lon PROP_FIPSCD_from  \
# Y39394000231102  124297011.0  37.982800 -121.83700            06013
# Y39394000242239   52245208.0  37.926600 -122.38900            06013
# Y39394000314991  186863857.0  37.774000 -122.26000            06001
# Y39394000381839   47811725.0  37.577400 -121.99300            06001
# Y39394000381839   83668792.0  37.751273 -122.43469            06075
#
#                 PROP_CENSUSTRACT_from PROP_MUNINAME_from PROP_OWNEROCC_from  \
# Y39394000231102            3551072003                NaN                  O
# Y39394000242239            3780001182                NaN                  A
# Y39394000314991            4279004000     ALAMEDA INCORP                  A
# Y39394000381839            4412002003     FREMONT INCORP                  O
# Y39394000381839            0212002008                NaN                NaN
#
#                 PROP_QLTY_from  PROP_VALCALC_from  PROP_UNVBLDSQFT_from  ...  \
# Y39394000231102            QGO           316975.0                2522.0  ...
# Y39394000242239            NaN           331019.0                1697.0  ...
# Y39394000314991            QAV           309321.0                1621.0  ...
# Y39394000381839            QAV           355445.0                1140.0  ...
# Y39394000381839            NaN          1009257.0                3175.0  ...
#
#                  to_effdate      distance   AGE   LOR HOMEOWNERCD EHI PCTB  \
# Y39394000231102    201007.0  20241.509295  93.0   3.0         NaN   A    S
# Y39394000242239    201610.0   8068.106654  93.0  15.0           H   D    S
# Y39394000314991    201706.0   1601.150776  48.0   8.0           H   G    R
# Y39394000381839    201304.0  21687.900364  76.0   6.0           R   G    T
# Y39394000381839    200310.0  43484.264229  76.0   6.0           R   G    T
#
#                 PCTW PCTH  PCTA
# Y39394000231102    F    P     S
# Y39394000242239    F    Q     S
# Y39394000314991    P    R     L
# Y39394000381839    H    R     P
# Y39394000381839    H    R     P
#
# [5 rows x 32 columns]

# %%
num_total_moves = len(moves)
num_moves_w_demog = len(moves_w_demog)

# %%
print('Matched movers to demographic profiles '
      'for {0} of {1} ({2}%) of relocation records.'.format(
        str(num_moves_w_demog), str(num_total_moves), str(round(100 * num_moves_w_demog / num_total_moves, 1))))
# Out:
# Matched movers to demographic profiles for 2832194 of 4610235 (61.4%) of relocation records.

# %% [markdown]
# ### Save results

# %%
moves_w_demog.to_csv('../data/movers.csv')
